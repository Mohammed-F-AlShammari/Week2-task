# %% [markdown]
# # Weekly Project 2!

# %% [markdown]
# ## Introduction to Road Traffic Accidents (RTA) Dataset
#
# ### Dataset Overview
# The RTA Dataset provides a detailed snapshot of road traffic accidents, capturing a range of data from accident conditions to casualty details. This dataset is essential for analyzing patterns and causes of accidents to improve road safety.
#
# ### Data Characteristics
# - **Entries**: The dataset contains 12,316 entries.
# - **Features**: There are 32 features in the dataset, which include:
#   - `Time`: Time when the accident occurred.
#   - `Day_of_week`: Day of the week.
#   - `Age_band_of_driver`: Age group of the driver involved.
#   - `Sex_of_driver`: Gender of the driver.
#   - `Educational_level`: Educational level of the driver.
#   - `Type_of_vehicle`: Type of vehicle involved in the accident.
#   - `Cause_of_accident`: Reported cause of the accident.
#   - `Accident_severity`: Severity of the accident.
# - **Target Column**: `Accident_severity` is used as the target column for modeling. This feature classifies the severity of each accident.
#
# ### Objective
# Students will use this dataset to apply various data visualization, modeling, and evaluation techniques learned in class. The primary goal is to build models that can accurately predict the severity of accidents and to identify the key factors that contribute to severe accidents.

# %% [markdown]
# ## Import Libraries
# Import all the necessary libraries here. Include libraries for handling data (like pandas), visualization (like matplotlib and seaborn), and modeling (like scikit-learn).

# %%
import pandas as pd

# %% [markdown]
# ## Load Data
# Load the dataset from the provided CSV file into a DataFrame.

# %%
df= pd.read_csv('RTA_Dataset.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Perform EDA to understand the data better. This involves several steps to summarize the main characteristics, uncover patterns, and establish relationships:
# * Find the dataset information and observe the datatypes.
# * Check the shape of the data to understand its structure.
# * View the the data with various functions to get an initial sense of the data.
# * Perform summary statistics on the dataset to grasp central tendencies and variability.
# * Check for duplicated data.
# * Check for null values.
#
# And apply more if needed!

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8914   17:30:00     Tuesday            Over 51          Male
# 11271  13:29:00    Saturday              18-30          Male
# 5986   15:34:00      Monday            Unknown          Male
# 2731   13:58:00      Friday              31-50          Male
# 10099  10:04:00   Wednesday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8914          High school                   Owner         Above 10yr
# 11271  Junior high school                Employee         Above 10yr
# 5986   Junior high school                Employee         Above 10yr
# 2731          High school                   Owner          Below 1yr
# 10099  Junior high school                Employee         Above 10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 8914               NaN            Owner                     NaN  ...
# ...

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df['Day_of_week'].mode()
# Out:
# 0    Friday
# Name: Day_of_week, dtype: object

# %%
df['Number_of_casualties'].mean()
# Out:
# 1.548148749594024

# %%
df['Educational_level'].mode()
# Out:
# 0    Junior high school
# Name: Educational_level, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df['Day_of_week'].unique()
# Out:
# array(['Monday', 'Sunday', 'Friday', 'Wednesday', 'Saturday', 'Thursday',
#        'Tuesday'], dtype=object)

# %%
df['Age_band_of_driver'].unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Educational_level'].unique()
# Out:
# array(['Above high school', 'Junior high school', nan,
#        'Elementary school', 'High school', 'Unknown', 'Illiterate',
#        'Writing & reading'], dtype=object)

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', nan, 'Other'], dtype=object)

# %%
df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %%
df['Owner_of_vehicle'].unique()
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
df['Service_year_of_vehicle'].unique()
# Out:
# array(['Above 10yr', '5-10yrs', nan, '1-2yr', '2-5yrs', 'Unknown',
#        'Below 1yr'], dtype=object)

# %%
df['Defect_of_vehicle'].unique()
# Out:
# array(['No defect', nan, '7', '5'], dtype=object)

# %%
df['Area_accident_occured'].unique()
# Out:
# array(['Residential areas', 'Office areas', '  Recreational areas',
#        ' Industrial areas', nan, 'Other', ' Church areas',
#        '  Market areas', 'Unknown', 'Rural village areas',
#        ' Outside rural areas', ' Hospital areas', 'School areas',
#        'Rural village areasOffice areas', 'Recreational areas'],
#       dtype=object)

# %%
df['Lanes_or_Medians'].unique()
# Out:
# array([nan, 'Undivided Two way', 'other', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)', 'Unknown'],
#       dtype=object)

# %%
df['Road_allignment'].unique()
# Out:
# array(['Tangent road with flat terrain', nan,
#        'Tangent road with mild grade and flat terrain', 'Escarpments',
#        'Tangent road with rolling terrain', 'Gentle horizontal curve',
#        'Tangent road with mountainous terrain and',
#        'Steep grade downward with mountainous terrain',
#        'Sharp reverse curve',
#        'Steep grade upward with mountainous terrain'], dtype=object)

# %%
df['Types_of_Junction'].unique()
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'Unknown', 'T Shape', 'X Shape', nan], dtype=object)

# %%
df['Road_surface_type'].unique()
# Out:
# array(['Asphalt roads', 'Earth roads', nan,
#        'Asphalt roads with some distress', 'Gravel roads', 'Other'],
#       dtype=object)

# %%
df['Road_surface_conditions'].unique()
# Out:
# array(['Dry', 'Wet or damp', 'Snow', 'Flood over 3cm. deep'], dtype=object)

# %%
df['Light_conditions'].unique()
# Out:
# array(['Daylight', 'Darkness - lights lit', 'Darkness - no lighting',
#        'Darkness - lights unlit'], dtype=object)

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Normal', 'Raining', 'Raining and Windy', 'Cloudy', 'Other',
#        'Windy', 'Snow', 'Unknown', 'Fog or mist'], dtype=object)

# %%
df['Type_of_collision'].unique()
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train', 'Unknown', nan],
#       dtype=object)

# %%
df['Number_of_vehicles_involved'].unique()
# Out:
# array([2, 1, 3, 6, 4, 7], dtype=int64)

# %%
df['Number_of_casualties'].unique()
# Out:
# array([2, 1, 3, 4, 6, 5, 8, 7], dtype=int64)

# %%
df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
df['Casualty_class'].unique()
# Out:
# array(['na', 'Driver or rider', 'Pedestrian', 'Passenger'], dtype=object)

# %%
df['Sex_of_casualty'].unique()
# Out:
# array(['na', 'Male', 'Female'], dtype=object)

# %%
df['Age_band_of_casualty'].unique()
# Out:
# array(['na', '31-50', '18-30', 'Under 18', 'Over 51', '5'], dtype=object)

# %%
df['Casualty_severity'].unique()
# Out:
# array(['na', '3', '2', '1'], dtype=object)

# %%
df['Work_of_casuality'].unique()
# Out:
# array([nan, 'Driver', 'Other', 'Unemployed', 'Employee', 'Self-employed',
#        'Student', 'Unknown'], dtype=object)

# %%
df['Fitness_of_casuality'].unique()
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
df['Pedestrian_movement'].unique()
# Out:
# array(['Not a Pedestrian', "Crossing from driver's nearside",
#        'Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle',
#        'Unknown or other',
#        'Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)',
#        'Walking along in carriageway, back to traffic',
#        'Walking along in carriageway, facing traffic',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'],
#       dtype=object)

# %%
df['Cause_of_accident'].unique()
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving at high speed', 'Driving to the left', 'Unknown',
#        'Overturning', 'Turnover', 'Driving under the influence of drugs',
#        'Drunk driving'], dtype=object)

# %%
df['Accident_severity'].unique()
# Out:
# array(['Slight Injury', 'Serious Injury', 'Fatal injury'], dtype=object)

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing is essential for transforming raw data into a format suitable for further analysis and modeling. Follow these steps to ensure your data is ready for predictive modeling or advanced analytics:
# - **Handling Missing Values**: Replace missing values with appropriate statistics (mean, median, mode) or use more complex imputation techniques.
# - **Normalization/Scaling**: Scale data to a small, specified range like 0 to 1, or transform it to have a mean of zero and a standard deviation of one.
# - **Label Encoding**: Convert categorical text data into model-understandable numbers where the labels are ordered.
# - **One-Hot Encoding**: Use for nominal categorical data where no ordinal relationship exists to transform the data into a binary column for each category. (Be careful not to increase the dimensionality significantly)
# - **Detection and Treatment of Outliers**: Use statistical tests, box plots, or scatter plots to identify outliers and then cap, trim, or use robust methods to reduce the effect of outliers, depending on the context.
# - **Feature Engineering**: Enhance your dataset by creating new features and transforming existing ones. This might involve combining data from different columns, applying transformations, or reducing dimensionality with techniques like PCA to improve model performance.
#
# Consider these steps as a foundation, and feel free to introduce additional preprocessing techniques as needed to address specific characteristics of your dataset.

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].str.replace('Unknown', 'Other')

# %%
df['Area_accident_occured'] = df['Area_accident_occured'].str.replace('Unknown', 'Other')
df['Area_accident_occured'] = df['Area_accident_occured'].str.replace('Rural village areasOffice areas', 'Other')

# %%
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].str.replace('Unknown', 'other')
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].str.replace('other', 'Other')

# %%
df['Types_of_Junction'] = df['Types_of_Junction'].str.replace('Unknown', 'Other')

# %%
df['Weather_conditions'] = df['Weather_conditions'].str.replace('Unknown', 'Other')

# %%
df['Type_of_collision'] = df['Type_of_collision'].str.replace('Unknown', 'Other')

# %%
df['Vehicle_movement'] = df['Vehicle_movement'].str.replace('Unknown', 'Other')

# %%
df['Age_band_of_casualty'] = df['Age_band_of_casualty'].str.replace('5', 'Under 18')

# %%
df['Work_of_casuality'] = df['Work_of_casuality'].str.replace('Unknown', 'Other')

# %%
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].str.replace('NormalNormal', 'Normal')

# %%
df['Cause_of_accident'] = df['Cause_of_accident'].str.replace('Unknown', 'Other')

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
def fill_mode(series):
    mode_value = series.mode()
    if not mode_value.empty:
        return series.fillna(mode_value[0])
    return series

# %%
df['Educational_level'] = df.groupby(['Sex_of_driver', 'Age_band_of_driver'])['Educational_level'].transform(fill_mode)
df['Vehicle_driver_relation'] = df.groupby(['Sex_of_driver', 'Age_band_of_driver'])['Vehicle_driver_relation'].transform(fill_mode)
df['Driving_experience'] = df.groupby('Age_band_of_driver')['Driving_experience'].transform(fill_mode)
df['Type_of_vehicle'] = df.groupby(['Road_surface_conditions', 'Weather_conditions'])['Type_of_vehicle'].transform(fill_mode)
df['Owner_of_vehicle'] = df.groupby('Age_band_of_driver')['Owner_of_vehicle'].transform(fill_mode)
df['Service_year_of_vehicle'] = df.groupby(['Sex_of_driver', 'Age_band_of_driver'])['Service_year_of_vehicle'].transform(fill_mode)
df['Defect_of_vehicle'] = df.groupby(['Road_surface_conditions', 'Cause_of_accident'])['Defect_of_vehicle'].transform(fill_mode)
df['Area_accident_occured'] = df.groupby(['Light_conditions', 'Weather_conditions', 'Road_surface_conditions'])['Area_accident_occured'].transform(fill_mode)
df['Lanes_or_Medians'] = df.groupby(['Road_surface_conditions', 'Cause_of_accident'])['Lanes_or_Medians'].transform(fill_mode)
df['Road_allignment'] = df.groupby(['Light_conditions', 'Weather_conditions', 'Road_surface_conditions'])['Road_allignment'].transform(fill_mode)
df['Types_of_Junction'] = df.groupby(['Cause_of_accident', 'Pedestrian_movement', 'Accident_severity'])['Types_of_Junction'].transform(fill_mode)
df['Road_surface_type'] = df.groupby(['Light_conditions', 'Weather_conditions', 'Road_surface_conditions'])['Road_surface_type'].transform(fill_mode)
df['Type_of_collision'] = df.groupby(['Cause_of_accident', 'Pedestrian_movement', 'Accident_severity'])['Type_of_collision'].transform(fill_mode)
df['Vehicle_movement'] = df.groupby(['Pedestrian_movement', 'Road_surface_conditions'])['Vehicle_movement'].transform(fill_mode)
df['Work_of_casuality'] = df.groupby(['Age_band_of_casualty', 'Sex_of_casualty'])['Work_of_casuality'].transform(fill_mode)
df['Fitness_of_casuality'] = df.groupby(['Pedestrian_movement', 'Age_band_of_casualty'])['Fitness_of_casuality'].transform(fill_mode)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              1
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              4
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
import numpy as np

# %%
df['Casualty_severity'] = df['Casualty_severity'].replace('na', np.nan)
df['Casualty_severity'] = df['Casualty_severity'].fillna('-1')

# %%
df['Casualty_severity'] = df['Casualty_severity'].astype(int)
df['Casualty_severity'] = df['Casualty_severity'].replace(-1, np.nan)

# %%
df['Casualty_severity'] = df.groupby( 'Age_band_of_casualty')['Casualty_severity'].transform(fill_mode)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Service_year_of_vehicle           0
# Defect_of_vehicle                 0
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction                 0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_20980\720567676.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0 2024-08-01 17:02:00      Monday              18-30          Male
# 1 2024-08-01 17:02:00      Monday              31-50          Male
# 2 2024-08-01 17:02:00      Monday              18-30          Male
# 3 2024-08-01 01:06:00      Sunday              18-30          Male
# 4 2024-08-01 01:06:00      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0           Automobile            Owner              Above 10yr  ...
# ...

# %%
df1 = df

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df1['Young_driver'] = df['Age_band_of_driver'] == 'Under 18'

# %%
df1['Young_driver']
# Out:
# 2        False
# 3        False
# 5        False
# 6        False
# 8        False
#          ...
# 12305    False
# 12309    False
# 12310    False
# 12313    False
# 12315    False
# Name: Young_driver, Length: 7868, dtype: bool

# %%
df1.select_dtypes(exclude=['number'])
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2     2024-08-01 17:02:00      Monday              18-30          Male
# 3     2024-08-01 01:06:00      Sunday              18-30          Male
# 5     2024-08-01 14:15:00      Friday              31-50          Male
# 6     2024-08-01 17:30:00   Wednesday              18-30          Male
# 8     2024-08-01 17:20:00      Friday              18-30          Male
# ...                   ...         ...                ...           ...
# 12305 2024-08-01 07:10:00      Friday              18-30          Male
# 12309 2024-08-01 09:05:00      Friday              31-50        Female
# 12310 2024-08-01 09:05:00      Friday              18-30          Male
# 12313 2024-08-01 13:55:00      Sunday            Over 51          Male
# 12315 2024-08-01 13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# ...

# %%
df1.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2 2024-08-01 17:02:00      Monday              18-30          Male
# 3 2024-08-01 01:06:00      Sunday              18-30          Male
# 5 2024-08-01 14:15:00      Friday              31-50          Male
# 6 2024-08-01 17:30:00   Wednesday              18-30          Male
# 8 2024-08-01 17:20:00      Friday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 5  Junior high school                   Other             5-10yr
# 6  Junior high school                Employee              2-5yr
# 8  Junior high school                Employee         Above 10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2      Lorry (41?100Q)            Owner                 Unknown  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
st_scaler = StandardScaler()
le = LabelEncoder()

# %%
num = df1.select_dtypes(include='number')
num.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties  Casualty_severity
# 2                            2                     2                3.0
# 3                            2                     2                3.0
# 5                            1                     1                3.0
# 6                            1                     1                3.0
# 8                            2                     1                3.0

# %%
df1['Number_of_vehicles_involved'] = st_scaler.fit_transform(df1[['Number_of_vehicles_involved']])
df1['Number_of_casualties'] = st_scaler.fit_transform(df1[['Number_of_casualties']])
df1['Casualty_severity'] = st_scaler.fit_transform(df1[['Casualty_severity']])

# %%
df1.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2 2024-08-01 17:02:00      Monday              18-30          Male
# 3 2024-08-01 01:06:00      Sunday              18-30          Male
# 5 2024-08-01 14:15:00      Friday              31-50          Male
# 6 2024-08-01 17:30:00   Wednesday              18-30          Male
# 8 2024-08-01 17:20:00      Friday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 5  Junior high school                   Other             5-10yr
# 6  Junior high school                Employee              2-5yr
# 8  Junior high school                Employee         Above 10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2      Lorry (41?100Q)            Owner                 Unknown  ...
# ...

# %%
df1['Day_of_week'] = le.fit_transform(df1['Day_of_week'])
df1['Age_band_of_driver'] = le.fit_transform(df1['Age_band_of_driver'])
df1['Sex_of_driver'] = le.fit_transform(df1['Sex_of_driver'])
df1['Educational_level'] = le.fit_transform(df1['Educational_level'])
df1['Vehicle_driver_relation'] = le.fit_transform(df1['Vehicle_driver_relation'])
df1['Driving_experience'] = le.fit_transform(df1['Driving_experience'])
df1['Type_of_vehicle'] = le.fit_transform(df1['Type_of_vehicle'])
df1['Owner_of_vehicle'] = le.fit_transform(df1['Owner_of_vehicle'])
df1['Service_year_of_vehicle'] = le.fit_transform(df1['Service_year_of_vehicle'])
df1['Defect_of_vehicle'] = le.fit_transform(df1['Defect_of_vehicle'])
df1['Area_accident_occured'] = le.fit_transform(df1['Area_accident_occured'])
df1['Lanes_or_Medians'] = le.fit_transform(df1['Lanes_or_Medians'])
df1['Road_allignment'] = le.fit_transform(df1['Road_allignment'])
df1['Types_of_Junction'] = le.fit_transform(df1['Types_of_Junction'])
df1['Road_surface_type'] = le.fit_transform(df1['Road_surface_type'])
df1['Road_surface_conditions'] = le.fit_transform(df1['Road_surface_conditions'])
df1['Light_conditions'] = le.fit_transform(df1['Light_conditions'])
df1['Weather_conditions'] = le.fit_transform(df1['Weather_conditions'])
df1['Type_of_collision'] = le.fit_transform(df1['Type_of_collision'])
df1['Vehicle_movement'] = le.fit_transform(df1['Vehicle_movement'])
df1['Casualty_class'] = le.fit_transform(df1['Casualty_class'])
df1['Age_band_of_casualty'] = le.fit_transform(df1['Age_band_of_casualty'])
df1['Work_of_casuality'] = le.fit_transform(df1['Work_of_casuality'])
df1['Fitness_of_casuality'] = le.fit_transform(df1['Fitness_of_casuality'])
df1['Pedestrian_movement'] = le.fit_transform(df1['Pedestrian_movement'])
df1['Cause_of_accident'] = le.fit_transform(df1['Cause_of_accident'])
df1['Accident_severity'] = le.fit_transform(df1['Accident_severity'])
df1['Young_driver'] = le.fit_transform(df1['Young_driver'])
df1['Sex_of_casualty'] = le.fit_transform(df1['Sex_of_casualty'])

# %%
df1.head()
# Out:
#                  Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 2 2024-08-01 17:02:00            1                   0              1
# 3 2024-08-01 01:06:00            3                   0              1
# 5 2024-08-01 14:15:00            0                   1              1
# 6 2024-08-01 17:30:00            6                   0              1
# 8 2024-08-01 17:20:00            0                   0              1
#
#    Educational_level  Vehicle_driver_relation  Driving_experience  \
# 2                  4                        0                   0
# 3                  4                        0                   2
# 5                  4                        1                   2
# 6                  4                        0                   1
# 8                  4                        0                   3
#
#    Type_of_vehicle  Owner_of_vehicle  Service_year_of_vehicle  ...  \
# 2                5                 3                        5  ...
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity', 'Young_driver'],
#       dtype='object')

# %%
corr_n = df1[['Area_accident_occured','Pedestrian_movement','Cause_of_accident','Casualty_severity','Accident_severity']]
corr_d = corr_n.corr()
sns.heatmap(corr_d, annot=True)
# Out:
# <Axes: >

# %%
corr_n = df1[['Driving_experience','Age_band_of_driver','Educational_level','Casualty_severity','Type_of_vehicle','Accident_severity']]
corr_d = corr_n.corr()
sns.heatmap(corr_d, annot=True)
# Out:
# <Axes: >

# %%
corr_n = df1[['Number_of_vehicles_involved','Service_year_of_vehicle','Number_of_casualties','Casualty_severity','Age_band_of_casualty','Accident_severity']]
corr_d1 = corr_n.corr()
sns.heatmap(corr_d1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Visualization
# Create various plots to visualize the relationships in the data. Consider using the following to show different aspects of the data:
#
# * Heatmap of Correlation Matrix.
# * Line plots.
# * Scatter plots.
# * Histograms.
# * Boxplots.
#
# Use more if needed!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(corr_d, annot=True)
plt.show()

# %%
sns.pairplot(corr_d)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df1, x='Number_of_casualties', y='Number_of_vehicles_involved')
plt.title('Relationship between Number_of_vehicles_involved and Number_of_casualties ')
plt.xlabel('Number_of_vehicles_involved')
plt.ylabel('Number_of_casualties')
plt.show()

# %%
n= df1.select_dtypes(include='number')
plt.figure(figsize=(12,6))
plt.boxplot(n)
plt.title('Box Plot')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# ## Feature Selection
# - Choose features that you believe will most influence the outcome based on your analysis and the insights from your visualizations. Focus on those that appear most impactful to include in your modeling.
#
# ## Train-Test Split
# * Divide the dataset into training and testing sets to evaluate the performance of your models.

# %%
x = df1['Number_of_vehicles_involved']
y = df1['Number_of_casualties']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# ## Modeling
#
# Once the data is split into training and testing sets, the next step is to build models to make predictions. Here, we will explore several machine learning algorithms, each with its unique characteristics and suitability for different types of data and problems. You will implement the following models:
#
# ### 1. Logistic Regression
#
# ### 2. Decision Tree Classifier
#
# ### 3. Support Vector Machine (SVM)
#
# ### 4. K-Neighbors Classifier
#
# ### Implementing the Models
# - For each model, use the training data you have prepared to train the model.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Assuming X and y are defined
log_reg = LogisticRegression(solver="lbfgs", random_state=42)
log_reg.fit(x_train, y_train)

y_hat_log_reg = log_reg.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[564], line 5
#       3 # Assuming X and y are defined
#       4 log_reg = LogisticRegression(solver="lbfgs", random_state=42)
# ----> 5 log_reg.fit(x_train, y_train)
#       7 y_hat_log_reg = log_reg.predict(x_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1208, in LogisticRegression.fit(self, X, y, sample_weight)
# ...

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)

tree_clf.fit(x_train, y_train)

y_hat_tree_clf = tree_clf.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[565], line 5
#       1 from sklearn.tree import DecisionTreeClassifier
#       3 tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
# ----> 5 tree_clf.fit(x_train, y_train)
#       7 y_hat_tree_clf = tree_clf.predict(x_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import LinearSVC
polynomial_svm_clf = Pipeline([
    ("poly_features", PolynomialFeatures(degree=3)),
    ("svm_clf", LinearSVC(C=100, loss='hinge', random_state=42)),
])

polynomial_svm_clf.fit(x_train, y_train)
y_hat_polynomial_svm_clf = polynomial_svm_clf.pridect(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[566], line 9
#       3 from sklearn.svm import LinearSVC
#       4 polynomial_svm_clf = Pipeline([
#       5     ("poly_features", PolynomialFeatures(degree=3)),
#       6     ("svm_clf", LinearSVC(C=100, loss='hinge', random_state=42)),
#       7 ])
# ----> 9 polynomial_svm_clf.fit(x_train, y_train)
#      10 y_hat_polynomial_svm_clf = polynomial_svm_clf.pridect(x_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# #### K-Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(weights='distance', n_neighbors=4)

knn_clf.fit(x_train, y_train)

y_hat_knn_clf = tree_clf.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[567], line 4
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 knn_clf = KNeighborsClassifier(weights='distance', n_neighbors=4)
# ----> 4 knn_clf.fit(x_train, y_train)
#       6 y_hat_knn_clf = tree_clf.predict(x_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# ## Model Evaluation
#
# After training your models, it's crucial to evaluate their performance to understand their effectiveness and limitations. This section outlines various techniques and metrics to assess the performance of each model you have implemented.
#
# ### Evaluation Techniques
# 1. **Confusion Matrix**
#
# 2. **Accuracy**
#
# 3. **Precision and Recall**
#
# 4. **F1 Score**
#
# 5. **ROC Curve and AUC**
#
# ### Implementing Evaluation
# - Calculate the metrics listed above using your test data.

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_curve, roc_auc_score

# %%
conf_mx = confusion_matrix(y_train, y_hat_knn_clf)
conf_mx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[577], line 1
# ----> 1 conf_mx = confusion_matrix(y_train, y_hat_knn_clf)
#       2 conf_mx
#
# NameError: name 'y_hat_knn_clf' is not defined

# %%
print('Logistic Regression accuracy_score is: ', accuracy_score(y_train, y_hat_log_reg))
print('Decision Tree Classifier accuracy_score is: ', accuracy_score(y_train, y_hat_tree_clf))
print('Support Vector Machine accuracy_score is: ', accuracy_score(y_train, y_hat_polynomial_svm_clf))
print('K-Neighbors Classifier accuracy_score is: ', accuracy_score(y_train, y_hat_knn_clf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[578], line 1
# ----> 1 print('Logistic Regression accuracy_score is: ', accuracy_score(y_train, y_hat_log_reg))
#       2 print('Decision Tree Classifier accuracy_score is: ', accuracy_score(y_train, y_hat_tree_clf))
#       3 print('Support Vector Machine accuracy_score is: ', accuracy_score(y_train, y_hat_polynomial_svm_clf))
#
# NameError: name 'y_hat_log_reg' is not defined

# %%
print('Logistic Regression accuracy_score is: ', recall_score(y_train, y_hat_log_reg))
print('Decision Tree Classifier accuracy_score is: ', recall_score(y_train, y_hat_tree_clf))
print('Support Vector Machine accuracy_score is: ', recall_score(y_train, y_hat_polynomial_svm_clf))
print('K-Neighbors Classifier accuracy_score is: ', recall_score(y_train, y_hat_knn_clf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[579], line 1
# ----> 1 print('Logistic Regression accuracy_score is: ', recall_score(y_train, y_hat_log_reg))
#       2 print('Decision Tree Classifier accuracy_score is: ', recall_score(y_train, y_hat_tree_clf))
#       3 print('Support Vector Machine accuracy_score is: ', recall_score(y_train, y_hat_polynomial_svm_clf))
#
# NameError: name 'y_hat_log_reg' is not defined

# %%
print('Logistic Regression accuracy_score is: ', precision_score(y_train, y_hat_log_reg))
print('Decision Tree Classifier accuracy_score is: ', precision_score(y_train, y_hat_tree_clf))
print('Support Vector Machine accuracy_score is: ', precision_score(y_train, y_hat_polynomial_svm_clf))
print('K-Neighbors Classifier accuracy_score is: ', precision_score(y_train, y_hat_knn_clf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[580], line 1
# ----> 1 print('Logistic Regression accuracy_score is: ', precision_score(y_train, y_hat_log_reg))
#       2 print('Decision Tree Classifier accuracy_score is: ', precision_score(y_train, y_hat_tree_clf))
#       3 print('Support Vector Machine accuracy_score is: ', precision_score(y_train, y_hat_polynomial_svm_clf))
#
# NameError: name 'y_hat_log_reg' is not defined

# %%
f1 = f1_score(y, y_hat_knn_clf)
print(f"F1 Score: {f1}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[581], line 1
# ----> 1 f1 = f1_score(y, y_hat_knn_clf)
#       2 print(f"F1 Score: {f1}")
#
# NameError: name 'y_hat_knn_clf' is not defined

# %% [markdown]
# ## Project Questions:
#
# ### Comparative Analysis
#
# - **Compare Metrics**: Examine the performance metrics (such as accuracy, precision, and recall) of each model. Document your observations on which model performs best for your dataset and the problem you're addressing.
# - **Evaluate Trade-offs**: Discuss the trade-offs you encountered when choosing between models. Consider factors like computational efficiency, ease of implementation, and model interpretability.
# - **Justify Your Choice**: After comparing and evaluating, explain why you believe one model is the best choice. Provide a clear rationale based on the performance metrics and trade-offs discussed.
# - **Feature Importance**: Identify and discuss the most important features for the best-performing model. How do these features impact the predictions? Use the visualizations you have created to justify your answer if necessary.
# - **Model Limitations**: Discuss any limitations you encountered with the models you used. Are there any aspects of the data or the problem that these models do not handle well?
# - **Future Improvements**: Suggest potential improvements or further steps you could take to enhance model performance. This could include trying different algorithms, feature engineering techniques, or tuning hyperparameters.

# %% [markdown]
# ### Answer Here:

# %% [markdown]
# ## i faced some problems with the data that results in un complition of the training
# ## i choosed x as Number_of_vehicles_involved and y as a Number_of_casualties because there is a pattern
